# %% [markdown]
# ## Image segmentation with CamVid

# %%
# !curl -s https://course.fast.ai/setup/colab | bash
#!curl https://course.fast.ai/setup/colab | bash
# Out:
# Updating fastai...
# Done.

# %%
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
root_dir = "/content/gdrive/My Drive/"
base_dir = root_dir + 'fastai-v3/'

# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
from fastai.vision import *
from fastai.callbacks.hooks import *
from fastai.utils.mem import *

# %%
path = untar_data(URLs.CAMVID)
path.ls()
# Out:
# Downloading https://s3.amazonaws.com/fast-ai-imagelocal/camvid
# [PosixPath('/root/.fastai/data/camvid/valid.txt'),
#  PosixPath('/root/.fastai/data/camvid/images'),
#  PosixPath('/root/.fastai/data/camvid/codes.txt'),
#  PosixPath('/root/.fastai/data/camvid/labels')]

# %%
path_lbl = path/'labels'
path_img = path/'images'

# %%
doc(SegmentationItemList)
# Out:
# <h2 id="SegmentationItemList" class="doc_header"><code>class</code> <code>SegmentationItemList</code><a href="https://github.com/fastai/fastai/blob/master/fastai/vision/data.py#L387" class="source_link" style="float:right">[source]</a><a class="source_link" data-toggle="collapse" data-target="#SegmentationItemList-pytest" style="float:right; padding-right:10px">[test]</a></h2><blockquote><p><code>SegmentationItemList</code>(<strong>*<code>args</code></strong>, <strong><code>convert_mode</code></strong>=<strong><em><code>'RGB'</code></em></strong>, <strong><code>after_open</code></strong>:<code>Callable</code>=<strong><em><code>None</code></em></strong>, <strong>**<code>kwargs</code></strong>) :: <a href="https://docs.fast.ai/vision.data.html#ImageList"><code>ImageList</code></a></p>
# </blockquote>
# <div class="collapse" id="SegmentationItemList-pytest"><div class="card card-body pytest_card"><a type="button" data-toggle="collapse" data-target="#SegmentationItemList-pytest" class="close" aria-label="Close"><span aria-hidden="true">&times;</span></a><p>Tests found for <code>SegmentationItemList</code>:</p><ul><li><code>pytest -sv tests/test_vision_data.py::test_camvid</code> <a href="https://github.com/fastai/fastai/blob/master/tests/test_vision_data.py#L243" class="source_link" style="float:right">[source]</a></li></ul><p>To run tests please refer to this <a href="/dev/test.html#quick-guide">guide</a>.</p></div></div><p><a href="https://docs.fast.ai/data_block.html#ItemList"><code>ItemList</code></a> suitable for segmentation tasks.</p>
# <p><a href="https://docs.fast.ai/vision.data.html#SegmentationItemList" target="_blank" rel="noreferrer noopener">Show in docs</a></p>

# %% [markdown]
# ## Subset classes

# %%
# path = Path('./data/camvid-small')

# def get_y_fn(x): return Path(str(x.parent)+'annot')/x.name

# codes = array(['Sky', 'Building', 'Pole', 'Road', 'Sidewalk', 'Tree',
#     'Sign', 'Fence', 'Car', 'Pedestrian', 'Cyclist', 'Void'])

# src = (SegmentationItemList.from_folder(path)
#        .split_by_folder(valid='val')
#        .label_from_func(get_y_fn, classes=codes))

# bs=8
# data = (src.transform(get_transforms(), tfm_y=True)
#         .databunch(bs=bs)
#         .normalize(imagenet_stats))

# %% [markdown]
# ## Data

# %%
fnames = get_image_files(path_img)
fnames[:3]
# Out:
# [PosixPath('/root/.fastai/data/camvid/images/0006R0_f02730.png'),
#  PosixPath('/root/.fastai/data/camvid/images/0016E5_08085.png'),
#  PosixPath('/root/.fastai/data/camvid/images/0016E5_08105.png')]

# %%
lbl_names = get_image_files(path_lbl)
lbl_names[:3]
# Out:
# [PosixPath('/root/.fastai/data/camvid/labels/0016E5_00840_P.png'),
#  PosixPath('/root/.fastai/data/camvid/labels/0006R0_f02730_P.png'),
#  PosixPath('/root/.fastai/data/camvid/labels/Seq05VD_f01680_P.png')]

# %%
img_f = fnames[4]
img = open_image(img_f)
img.show(figsize=(5,5))

# %%
get_y_fn = lambda x: path_lbl/f'{x.stem}_P{x.suffix}'

# %%
mask = open_mask(get_y_fn(img_f))
mask.show(figsize=(5,5), alpha=1)

# %%
src_size = np.array(mask.shape[1:])
src_size,mask.data
# Out:
# (array([720, 960]), tensor([[[ 4,  4,  4,  ..., 21, 21, 21],
#           [ 4,  4,  4,  ..., 21, 21, 21],
#           [ 4,  4,  4,  ..., 21, 21, 21],
#           ...,
#           [19, 19, 19,  ..., 17, 17, 17],
#           [19, 19, 19,  ..., 17, 17, 17],
#           [19, 19, 19,  ..., 17, 17, 17]]]))

# %%
codes = np.loadtxt(path/'codes.txt', dtype=str); codes
# Out:
# array(['Animal', 'Archway', 'Bicyclist', 'Bridge', 'Building', 'Car', 'CartLuggagePram', 'Child', 'Column_Pole',
#        'Fence', 'LaneMkgsDriv', 'LaneMkgsNonDriv', 'Misc_Text', 'MotorcycleScooter', 'OtherMoving', 'ParkingBlock',
#        'Pedestrian', 'Road', 'RoadShoulder', 'Sidewalk', 'SignSymbol', 'Sky', 'SUVPickupTruck', 'TrafficCone',
#        'TrafficLight', 'Train', 'Tree', 'Truck_Bus', 'Tunnel', 'VegetationMisc', 'Void', 'Wall'], dtype='<U17')

# %% [markdown]
# ## Datasets

# %%
size = src_size//2

free = gpu_mem_get_free_no_cache()
# the max size of bs depends on the available GPU RAM
if free > 8200: bs=8
else:           bs=4
print(f"using bs={bs}, have {free}MB of GPU RAM free")
# Out:
# using bs=8, have 16270MB of GPU RAM free

# %%
src = (SegmentationItemList.from_folder(path_img)
       .split_by_fname_file('../valid.txt')
       .label_from_func(get_y_fn, classes=codes))

# %%
data = (src.transform(get_transforms(), size=size, tfm_y=True)
        .databunch(bs=bs)
        .normalize(imagenet_stats))

# %%
data.show_batch(2, figsize=(10,7))

# %%
data.show_batch(2, figsize=(10,7), ds_type=DatasetType.Valid)

# %% [markdown]
# ## Model

# %%
name2id = {v:k for k,v in enumerate(codes)}
void_code = name2id['Void']

def acc_camvid(input, target):
    target = target.squeeze(1)
    mask = target != void_code
    return (input.argmax(dim=1)[mask]==target[mask]).float().mean()

# %%
metrics=acc_camvid
# metrics=accuracy

# %%
wd=1e-2

# %%
learn = unet_learner(data, models.resnet34, metrics=metrics, wd=wd)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet34-333f7ec4.pth" to /root/.cache/torch/checkpoints/resnet34-333f7ec4.pth
# HBox(children=(IntProgress(value=0, max=87306240), HTML(value='')))

# %%
lr_find(learn)
learn.recorder.plot()
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='2', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/2 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>acc_camvid</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='69' class='' max='75', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       92.00% [69/75 00:51<00:04 5.0396]
#     </div>
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
3e-3
# Out:
# 0.003

# %%
lr=3e-3

# %%
learn.fit_one_cycle(10, slice(lr), pct_start=0.9)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>acc_camvid</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.183178</td>
#       <td>0.771677</td>
#       <td>0.811873</td>
#       <td>00:54</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.832497</td>
#       <td>0.695912</td>
#       <td>0.827122</td>
#       <td>00:51</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.687145</td>
#       <td>0.546615</td>
#       <td>0.861419</td>
#       <td>00:51</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.608166</td>
#       <td>0.479335</td>
#       <td>0.858911</td>
#       <td>00:50</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.607654</td>
#       <td>0.513766</td>
#       <td>0.851569</td>
#       <td>00:50</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.641579</td>
#       <td>0.483725</td>
#       <td>0.867022</td>
#       <td>00:50</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.587540</td>
#       <td>0.487590</td>
#       <td>0.855955</td>
#       <td>00:50</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.606033</td>
#       <td>0.770338</td>
#       <td>0.780760</td>
#       <td>00:50</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.568228</td>
#       <td>0.467321</td>
#       <td>0.872130</td>
#       <td>00:51</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.474996</td>
#       <td>0.352808</td>
#       <td>0.893907</td>
#       <td>00:50</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.save('stage-1')

# %%
learn.load('stage-1');

# %%
learn.show_results(rows=3, figsize=(8,9))

# %%
learn.unfreeze()

# %%
lrs = slice(lr/400,lr/4)

# %%
learn.fit_one_cycle(12, lrs, pct_start=0.8)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>acc_camvid</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.400231</td>
#       <td>0.349433</td>
#       <td>0.894113</td>
#       <td>00:53</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.390749</td>
#       <td>0.340690</td>
#       <td>0.899655</td>
#       <td>00:52</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.382138</td>
#       <td>0.349936</td>
#       <td>0.898026</td>
#       <td>00:52</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.372489</td>
#       <td>0.338770</td>
#       <td>0.899190</td>
#       <td>00:52</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.362582</td>
#       <td>0.350145</td>
#       <td>0.899170</td>
#       <td>00:53</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.348954</td>
#       <td>0.315314</td>
#       <td>0.909396</td>
#       <td>00:52</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.341256</td>
#       <td>0.339050</td>
#       <td>0.903097</td>
#       <td>00:53</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.334281</td>
#       <td>0.305089</td>
#       <td>0.917066</td>
#       <td>00:52</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.318875</td>
#       <td>0.308751</td>
#       <td>0.913990</td>
#       <td>00:52</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.301496</td>
#       <td>0.289987</td>
#       <td>0.920569</td>
#       <td>00:52</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.277010</td>
#       <td>0.281611</td>
#       <td>0.921418</td>
#       <td>00:52</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.254609</td>
#       <td>0.261208</td>
#       <td>0.926389</td>
#       <td>00:52</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.save('stage-2');

# %% [markdown]
# ## Go big

# %% [markdown]
# You may have to restart your kernel and come back to this stage if you run out of memory, and may also need to decrease `bs`.

# %%
learn.destroy()

size = src_size

free = gpu_mem_get_free_no_cache()
# the max size of bs depends on the available GPU RAM
if free > 8200: bs=3
else:           bs=1
print(f"using bs={bs}, have {free}MB of GPU RAM free")
# Out:
# this Learner object self-destroyed - it still exists, but no longer usable
# using bs=3, have 15559MB of GPU RAM free

# %%
data = (src.transform(get_transforms(), size=size, tfm_y=True)
        .databunch(bs=bs)
        .normalize(imagenet_stats))

# %%
learn = unet_learner(data, models.resnet34, metrics=metrics, wd=wd)

# %%
learn.load('stage-2');

# %%
lr_find(learn)
learn.recorder.plot()
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='1', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>acc_camvid</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='65' class='' max='200', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       32.50% [65/200 01:14<02:35 0.7860]
#     </div>
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
lr=1e-3

# %%
learn.fit_one_cycle(10, slice(lr), pct_start=0.8)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>acc_camvid</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.401826</td>
#       <td>0.348129</td>
#       <td>0.905406</td>
#       <td>03:37</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.370368</td>
#       <td>0.296511</td>
#       <td>0.918754</td>
#       <td>03:34</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.334291</td>
#       <td>0.343492</td>
#       <td>0.907965</td>
#       <td>03:34</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.344186</td>
#       <td>0.284064</td>
#       <td>0.925009</td>
#       <td>03:34</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.340013</td>
#       <td>0.255504</td>
#       <td>0.932673</td>
#       <td>03:34</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.344222</td>
#       <td>0.278325</td>
#       <td>0.926823</td>
#       <td>03:34</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.334906</td>
#       <td>0.276879</td>
#       <td>0.925196</td>
#       <td>03:34</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.315209</td>
#       <td>0.288472</td>
#       <td>0.920104</td>
#       <td>03:34</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.285837</td>
#       <td>0.257830</td>
#       <td>0.927594</td>
#       <td>03:34</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.239031</td>
#       <td>0.249376</td>
#       <td>0.930338</td>
#       <td>03:34</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.save('stage-1-big')

# %%
learn.load('stage-1-big');

# %%
learn.unfreeze()

# %%
lrs = slice(1e-6,lr/10)

# %%
learn.fit_one_cycle(10, lrs)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>acc_camvid</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.229827</td>
#       <td>0.249251</td>
#       <td>0.930075</td>
#       <td>03:41</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.215477</td>
#       <td>0.246223</td>
#       <td>0.931597</td>
#       <td>03:41</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.220128</td>
#       <td>0.259398</td>
#       <td>0.928253</td>
#       <td>03:40</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.217065</td>
#       <td>0.241607</td>
#       <td>0.932819</td>
#       <td>03:41</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.214848</td>
#       <td>0.243508</td>
#       <td>0.932021</td>
#       <td>03:40</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.210063</td>
#       <td>0.243631</td>
#       <td>0.932489</td>
#       <td>03:40</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.204758</td>
#       <td>0.258321</td>
#       <td>0.927458</td>
#       <td>03:41</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.206300</td>
#       <td>0.247637</td>
#       <td>0.932390</td>
#       <td>03:40</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.194878</td>
#       <td>0.244107</td>
#       <td>0.933443</td>
#       <td>03:40</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.196190</td>
#       <td>0.245255</td>
#       <td>0.933245</td>
#       <td>03:40</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.save('stage-2-big')

# %%
learn.load('stage-2-big');

# %%
learn.show_results(rows=3, figsize=(10,10))

# %% [markdown]
# ## fin
